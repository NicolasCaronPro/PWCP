# %%
import pandas as pd

dataset = pd.read_csv('dataset_2023_calibrated.csv')

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

dataset[['0.0_0', 'prec24h_mean_0_0', 'NDMI_mean_0']] = StandardScaler().fit_transform(dataset[['0.0_0', 'prec24h_mean_0_0', 'NDMI_mean_0']])

# %%
dataset[['0.0_0', 'prec24h_mean_0_0', 'NDMI_mean_0']][:1000].plot()
# Out:
# <Axes: >
