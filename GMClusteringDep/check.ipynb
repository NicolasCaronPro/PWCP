# %%
import pandas as pd

# %%
dataset = pd.read_csv('Fire_2023_calibrated.csv')
dataset
# Out:
#        Unnamed: 0  departement  cluster     creneau  year  nbFire  isFire  \
# 0               0           25      265  2012-09-14  2012       1    True
# 1               1           25      265  2012-09-15  2012       0   False
# 2               2           25      265  2012-09-16  2012       0   False
# 3               3           25      265  2012-09-17  2012       1    True
# 4               4           25      265  2012-09-18  2012       0   False
# ...           ...          ...      ...         ...   ...     ...     ...
# 10232       10232           78      848  2023-10-10  2023       0   False
# 10233       10233           78      848  2023-10-11  2023       0   False
# 10234       10234           78      848  2023-10-12  2023       0   False
# 10235       10235           78      848  2023-10-13  2023       0   False
# 10236       10236           78      848  2023-10-14  2023       1    True
#
#        fire_last_7  fire_last_30  severity  influenceFire  \
# ...

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(20,5)) 

for dep in dataset.departement.unique():
    plt.plot(dataset[dataset['departement'] == dep].calibratedProbaFire, label=str(dep))

plt.legend()
